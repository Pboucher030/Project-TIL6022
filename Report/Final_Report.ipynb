# %% [markdown]
# # Research proposal TIL Programming:

# %% [markdown]
# ## Project Group 20
#
# Members and student numbers:
#
# - Stijn Brons - 5403707
# - Philippe Sturm - 5168163
# - Naut Linssen - 5032563
# - Pelle Boucher - 4885236
# - Teun van Wingerden - 5063108

# %% [markdown]
# # 1. Introduction
# Over the past decade, remote work has gained traction in the Netherlands, reshaping mobility and commuting patterns in the country. This research investigates the impact of increased remote work on various mobility trends, transportation choices, and their potential implications for urban planning and environmental sustainability. The study spans a ten-year period from 2013 to 2023, with a particular focus on the acceleration of remote work due to the COVID-19 pandemic. By analyzing data on commuting frequency, transport mode preferences, and emissions, this research aims to quantify the effects of remote work on travel demand, public transportation usage, and environmental impact, ultimately providing insights into how remote work has become an integral part of workplace culture in the Netherlands.

# %% [markdown]
# # 2. Main Research Objective
#
# The primary objective of this research is to quantify and analyze how the increase in remote work over the past decade has influenced mobility patterns, transport mode usage, and environmental impact in the Netherlands.

# %% [markdown]
# # 3. Research questions
# To address the main objective of understanding the impact of increased remote work on mobility in the Netherlands, the research has been divided into four key areas, each focusing on different aspects of this impact. Each area is represented by a research question aimed at examining specific changes over the past decade.
#
# - **RQ1**: How has the prevalence of remote work changed in the Netherlands over the past 10 years?
# - **RQ2**: How has the travel motive developed over the last 10 years?
# - **RQ3**: To what extent has remote work impacted the use of various transport modes over the past decade?
# - **RQ4**: How has the rise in remote work influenced transport-related emissions and air quality in the Netherlands?
#
# These questions together provide a comprehensive framework for analyzing the multifaceted effects of remote work on transportation and environmental sustainability.

# %% [markdown]
# # 4. Method
#
# ## Intended Data Pipeline
#
# ### Data Collection
# The primary data source for this research will be the CBS Statline database, which provides a wide range of data on mobility, transport, commuting patterns, and environmental factors.
#
# ### Data Sources
#
# All data will be collected from the **CBS Statline Database**. This will be the primary data source for mobility, transport usage, and environmental data over the past 10 years in the Netherlands. (Available at [CBS Statline](https://opendata.cbs.nl)).
#
# - **Mobility and Transport**: Data on trips, modes of transport, travel motives, age, and gender. (Available at [Mobiliteitstrend](https://opendata.cbs.nl/statline/#/CBS/nl/dataset/84755NED/table?ts=1727864298786)).
#
# - **Emissions and Air Quality**: Data on CO2 emissions, particulate matter levels, and other environmental metrics.
#
# - **Working from home**: Data on people working from home, per age group, education level, labour duration and position in the family Available at [Working from home](https://opendata.cbs.nl/statline/#/CBS/nl/dataset/83258NED/table?ts=1728062945121).
#
#
# The data is imported as an csv file and decoded below:
# ### Data Cleaning
# Data from CBS are be pre-processed to remove incomplete records, normalize values across different datasets, and ensure consistency in time-series data.
#
# ### Data Combination and integration
# In order get good results out of the data two datasets had to be combined. This were the two datasets about working from home, this is because one dataset had tot from 2013 til 2020 and the toher on had data from 2020 to 2023. Because both datasets using different words for the type of wokrers these words also had to be changed in order to get a good results out of it.
#
# ## Research
#
# ## Data Analysis
# Quantitative analysis will be performed to answer each research question:
# - Time-series analysis of mobility trends over the past decade.
# - Air quality and emissions analysis before and after the rise of remote work.
#
# ### Visualization
# The results will be visualized through:
# - Line graphs showing changes in commuting frequency and transport mode usage.
# - Bar chart showing changes in travel motives and transport mode usage.
# - Scatter plots showing a trend line based on data
#
# ### Time and Spatial Scale
#
# - **Time Scale**: The study will focus on a 10-year period, from 2013 to 2023, with a special focus on the years following the COVID-19 pandemic (2020–2023) due to the rapid adoption of remote work.
#
# - **Spatial Scale**: The geographical boundary will cover the entirety of the Netherlands, with a particular focus on urban centers (e.g., Amsterdam, Rotterdam, Utrecht) compared to rural areas. This will allow for regional comparison and identification of mobility trends in different parts of the country.

# %% [markdown]
# # 5. Results
#
# ### RQ1: How has the prevalence of remote work changed in the Netherlands over the past 10 years?
# The first research question explains how the prevalence of remote work in the Netherlands has changed over the last 10 years. This gives a good insight into the trend of working from home and how this will develop in the future years. Figure [1] shows the trend line of the number of people working from home in 2013 until 2023. The group of people working from home is defined as people who are always working from home and people who mostly or sometimes work from home. As can be seen in the figure, when the time passes more people are starting to work from home, with a clear increase in 2020. This increase is a result of the Covid crisis which started during this period (Rijksoverheid, 2024). Because people were not able to work in an office anymore due to the 1.5 meter restriction, they had to find another way to continue their work. That is why people started to work from home as can be seen in the figure. Following the spike in 2020, a significant proportion of employees have continued to work from home even after the conclusion of the crisis. The transition to remote work has had a significant and enduring impact, reducing the necessity for daily commuting for a considerable number of employees. It is anticipated that this reduction in physical commutes will have a considerable impact on overall travel demand and mobility patterns in the Netherlands, influencing both the use of public transportation and private car travel.
#
# ![Population working from home](attachment:image-2.png)
#
# *Figure [1]: Number of people working from home 2013 until 2023*
#
# In figure [2] the type of workers over the last 10 years is shown. The graph shows trends in remote working among workers, segmented by those who often work from home, sometimes work from home, and do not work from home. Over time, there has been a noticeable increase in both the number of people who sometimes and often work from home, particularly after 2020. This suggests a shift towards more flexible work arrangements, influenced by the COVID-19 pandemic, which led to a decline in the proportion of people who do not work from home.
#
# ![Types of remote workers](attachment:image.png)
#
# *Figure [2]: Types of remote workers 2013 until 2023*
#
# Figure [3] illustrates the percentage distribution of remote work from 2013 to 2023. It shows a steady increase in the proportion of people who sometimes work from home and a notable rise in the year 2020 where it rises from 23.1% to 33.3% This increase develops in the years after. Consequently, the percentage of workers who do not work from home has declined significantly, from about 65% in 2014 to around 48% in 2022. This shift highlights the growing trend towards flexible work arrangements, likely accelerated by the pandemic starting in 2020.
#
# ![Percentage of remote workers](attachment:image-3.png)
#
# *Figure [3]: Types of remote workers 2013 until 2023 expressed in percentages*
#
# Looking at the figures, it can be concluded that remote working had already been increasing over the past years, with COVID-19 accelerating this trend. The data shows that the category "Sometimes working from home" has grown significantly, indicating that working from home occasionally has become more normalized and is increasingly becoming part of workplace culture.

# %% [markdown]
# ### RQ2: How has the travel motive developed over the last 10 years?
#
# As could be seen in the first research question, there has been an increase in the number of people working from home in the past decade. Especially between 2020 and 2021. This was the period in which COVID-19 was growing and people could not leave their house if not necessary.
# Besides the growth in the number of people working from home this research also investigated the other travel motives over time. The figures below show the travel motives over the past few years. The first thing that can be noticed in figure [4] is that there is a slight decrease in the number of trips per day the past years with a big decrease in 2020. This is the consequence of COVID-19. Besides the number of trips, the travel motives ‘Education’ and ‘Working’ stand out when looking at the change in number of trips per travel motive in figure [5]. As mentioned in the answer of research question 1, this is the logic consequence after closing the schools and the advice to work from home as measures to prevent the spreading of COVID-19.
# Discussion: The dataset earlier in time has bigger time steps than the other dataset. The decrease and increase of the number of trips per day are therefore less accurate than when using the same time steps in both datasets
#
# ![Travel motives](attachment:image.png)
#
# Figure [4]: Different number of trips per day over time
#
# ![Travel motive percentages](attachment:image-2.png)
#
# Figure [5]: Percentage of different travel motives over time

# %% [markdown]
# ### Co2 emissions
#
# ![Co2 Emissions](Graphs/Co2_emissions.png)
#
# ![Emissions per mode](Graphs/Emissions_per_mode.png)
#
# ![Emissions road](Graphs/Emissions_road.png)
#
# ### Travel modes
#
# ![Travel modes](Graphs/Travel_modes.png)
#
# ![Travel mode percentages](Graphs/Travel_modes_pct.png)
# ![image-2.png](attachment:image-2.png)
#
# ### The effect of working from home on motives, emissions and travel modes

# %% [markdown]
# ### Co2 emissions
#
# ![Co2 Emissions](Graphs/Co2_emissions.png)
#
# ![Emissions per mode](Graphs/Emissions_per_mode.png)
#
# ![Emissions road](Graphs/Emissions_road.png)

# %% [markdown]
# # Conclusion
#
# # Discussion

# %% [markdown]
# # Contribution Statement
#
# **Author 1**: Pelle Boucher - Combining data for RQ1, Filtering, adding data (percentages) and visualizing for different research questions. Saving and importing graphs and setting up the final report file.
#
# **Author 2**: Teun van Wingerden - Writing text
#
# **Author 3**: Stijn Brons - Setting up the notebook, writing text, writing the code,
#
# **Author 4**: Philippe Sturm - Data Research
#
# **Author 5**: Naut Linssen - Data Research
#
# *Be specific. Some of the tasks can be coding (expect everyone to do this), background research, conceptualisation, visualisation, data analysis, data modelling*
